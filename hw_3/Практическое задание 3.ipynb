# %%
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount ('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %% [markdown]
# # Задания 1,2 - считать данные из файла и вывести основную информацию

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Задание 3  - процент выживаемости:

# %%
Sur=df.groupby("Pclass")["Survived"].sum()
Pcl=df.groupby('Pclass').count()
Tot=Pcl['PassengerId']
Per=Sur/Tot *100
Per
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# dtype: float64

# %% [markdown]
# В первом классе выжило 62,9% пассажиров, во втором - 47,3%, а в третьем - 24,2%

# %% [markdown]
# # Задания 4, 5 - самые популярные имена:

# %%
df_copy=df.copy(deep=True)
df_copy['Name1'] = df_copy['Name'].str.split(' ')
df_copy = df_copy.explode('Name1')
df_copy
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 0              1         0       3
# 0              1         0       3
# 0              1         0       3
# 1              2         1       1
# ..           ...       ...     ...
# 889          890         1       1
# 889          890         1       1
# 890          891         0       3
# 890          891         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_m=df_copy[df_copy["Sex"].isin(["male"])]
df_m.Name1.value_counts()
# Out:
# Name1
# Mr.         517
# William      47
# Master.      40
# John         36
# Henry        28
#            ...
# Partner,      1
# Austen        1
# Graham,       1
# Planke,       1
# Dooley,       1
# Name: count, Length: 1018, dtype: int64

# %%
df_fm=df_copy[df_copy["Sex"].isin(["female"])]
df_fm.Name1.value_counts()
# Out:
# Name1
# Miss.        182
# Mrs.         125
# William       15
# Mary          13
# Anna          11
#             ...
# Bechstein      1
# Borie          1
# Lahtinen,      1
# Sylfven)       1
# "Carrie"       1
# Name: count, Length: 841, dtype: int64

# %% [markdown]
# Самое популярное мужское имя - William,
# самое популярное женское  - Mary

# %%
df_1class=df_copy[df_copy['Pclass']==1]
df_m1=df_1class[df_1class["Sex"].isin(["male"])]
df_m1.Name1.value_counts()
# Out:
# Name1
# Mr.          107
# William       14
# John           9
# George         7
# Edward         6
#             ...
# Harder,        1
# Achilles       1
# Ringhini,      1
# Sante          1
# Howell         1
# Name: count, Length: 283, dtype: int64

# %%
df_fm1=df_1class[df_1class["Sex"].isin(["female"])]
df_fm1.Name1.value_counts()
# Out:
# Name1
# Miss.        46
# Mrs.         42
# Elizabeth     6
# William       5
# John          4
#              ..
# Atkinson)     1
# Aubart,       1
# Mme.          1
# Leontine      1
# Wilson)       1
# Name: count, Length: 324, dtype: int64

# %%
df_2class=df_copy[df_copy['Pclass']==2]
df_m2=df_2class[df_2class["Sex"].isin(["male"])]
df_m2.Name1.value_counts()
# Out:
# Name1
# Mr.         91
# William     13
# Henry       10
# John         9
# Charles      9
#             ..
# Hosono,      1
# Masabumi     1
# Levy,        1
# Jacques      1
# Juozas       1
# Name: count, Length: 218, dtype: int64

# %%
df_fm2=df_2class[df_2class["Sex"].isin(["female"])]
df_fm2.Name1.value_counts()
# Out:
# Name1
# Mrs.          41
# Miss.         34
# William        7
# (Elizabeth     5
# (Ada           4
#               ..
# "Mildred"      1
# Smith,         1
# Funk,          1
# Clemmer        1
# Parrish        1
# Name: count, Length: 246, dtype: int64

# %%
df_3class=df_copy[df_copy['Pclass']==3]
df_m3=df_3class[df_3class["Sex"].isin(["male"])]
df_m3.Name1.value_counts()
# Out:
# Name1
# Mr.        319
# Master.     28
# William     20
# John        18
# Henry       12
#           ...
# Bernard      1
# McCoy,       1
# Mansour      1
# Hanna,       1
# Dooley,      1
# Name: count, Length: 637, dtype: int64

# %%
df_fm3=df_3class[df_3class["Sex"].isin(["female"])]
df_fm3.Name1.value_counts()
# Out:
# Name1
# Miss.        102
# Mrs.          42
# Anna           9
# Mary           8
# Sofia          6
#             ...
# Thamine        1
# Phoebe         1
# Harknett,      1
# Gertrud        1
# "Carrie"       1
# Name: count, Length: 371, dtype: int64

# %% [markdown]
# Самые популярные имена в первом классе - William и Elizabeth, во втором - также William и Elizabeth, а в третьем - William и Anna

# %% [markdown]
# # Задания 6, 7 - таблицы с возрастами:

# %%
df[df['Age'] > 44]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 52            53         1       1
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df["Sex"].isin(["male"])) & (df['Age']>44)]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 33            34         0       2           Wheadon, Mr. Edward H  male
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius  male
# 62            63         0       1     Harris, Mr. Henry Birkhardt  male
# 92            93         0       1     Chaffee, Mr. Herbert Fuller  male
# ..           ...       ...     ...                             ...   ...
# 771          772         0       3         Jensen, Mr. Niels Peder  male
# 789          790         0       1        Guggenheim, Mr. Benjamin  male
# 851          852         0       3             Svensson, Mr. Johan  male
# 857          858         1       1          Daly, Mr. Peter Denis   male
# 873          874         0       3     Vander Cruyssen, Mr. Victor  male
#
#       Age  SibSp  Parch       Ticket     Fare    Cabin Embarked   Процент
# ...

# %% [markdown]
# # Задание 8 - количество многоместных кабин:

# %%
df1=df.groupby("Cabin")["PassengerId"].count()
df2=df1[df1>1]
df2.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 46 entries, B18 to G6
# Series name: PassengerId
# Non-Null Count  Dtype
# --------------  -----
# 46 non-null     int64
# dtypes: int64(1)
# memory usage: 736.0+ bytes

# %% [markdown]
# На корабле было 46 кают, занимаемых более чем одним пассажиром
